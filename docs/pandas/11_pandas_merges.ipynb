# %% [markdown]
# ## pandas.concat()
# - 중요점 : 같은 컬럼끼리 수직으로 붙임

# %%
import pandas as pd
df_BRAZIL = pd.read_csv('BRAZIL.csv')
df_ITALY = pd.read_csv('ITALY.csv')
df_USA = pd.read_csv('USA.csv')
df_merged = df_BRAZIL.shape,df_ITALY.shape,df_USA.shape
df_merged
# Out:
# ((10683, 9), (37986, 9), (179365, 9))

# %%
pd.concat(objs=[df_BRAZIL,df_ITALY,df_USA])
# Out:
#               Date        Country                 City      Specie  count  \
# 0       14-03-2021         BRAZIL  São José dos Campos    humidity     96
# 1       05-07-2021         BRAZIL  São José dos Campos    humidity     96
# 2       28-09-2021         BRAZIL  São José dos Campos    humidity     96
# 3       16-11-2021         BRAZIL  São José dos Campos    humidity     96
# 4       22-06-2021         BRAZIL  São José dos Campos    humidity     96
# ...            ...            ...                  ...         ...    ...
# 179360  05-02-2021  UNITED STATES           Fort Worth  wind-speed     23
# 179361  06-05-2021  UNITED STATES           Fort Worth  wind-speed     22
# 179362  29-05-2021  UNITED STATES           Fort Worth  wind-speed     22
# 179363  30-07-2021  UNITED STATES           Fort Worth  wind-speed     22
# 179364  15-08-2021  UNITED STATES           Fort Worth  wind-speed     22
#
#          min    max  median  variance
# 0       48.0  100.0    88.0   2415.31
# ...

# %%
df_BRAZIL
# Out:
#              Date Country                 City     Specie  count   min    max  \
# 0      14-03-2021  BRAZIL  São José dos Campos   humidity     96  48.0  100.0
# 1      05-07-2021  BRAZIL  São José dos Campos   humidity     96  49.0  100.0
# 2      28-09-2021  BRAZIL  São José dos Campos   humidity     96  23.0   93.0
# 3      16-11-2021  BRAZIL  São José dos Campos   humidity     96  26.0   88.0
# 4      22-06-2021  BRAZIL  São José dos Campos   humidity     96  82.0  100.0
# ...           ...     ...                  ...        ...    ...   ...    ...
# 10678  22-11-2021  BRAZIL            São Paulo  wind-gust    288   0.2   17.3
# 10679  15-04-2021  BRAZIL            São Paulo  wind-gust    234   0.4   12.9
# 10680  09-03-2021  BRAZIL            São Paulo  wind-gust    216   0.4   15.1
# 10681  14-11-2021  BRAZIL            São Paulo  wind-gust    264   1.7   18.0
# 10682  06-01-2021  BRAZIL            São Paulo  wind-gust    218   0.9   12.3
#
#        median  variance
# ...

# %%
df_ITALY
# Out:
#              Date Country     City Specie  count   min   max  median  variance
# 0      28-02-2021   Italy  Bologna    dew     46  -2.0   4.0     1.0     34.83
# 1      23-03-2021   Italy  Bologna    dew     46  -8.0  -1.0    -3.0     46.54
# 2      12-04-2021   Italy  Bologna    dew     34  10.0  14.0    11.0     13.71
# 3      15-07-2021   Italy  Bologna    dew     46  11.0  15.0    12.0     11.75
# 4      29-08-2021   Italy  Bologna    dew     40   5.0  11.5    10.0     49.56
# ...           ...     ...      ...    ...    ...   ...   ...     ...       ...
# 37981  20-05-2021   Italy    Parma    dew     34  -3.0   8.0     4.0    137.90
# 37982  07-09-2021   Italy    Parma    dew    104   9.0  12.0    10.0      6.93
# 37983  21-01-2021   Italy    Parma    dew     72   2.0   4.0     3.0      6.76
# 37984  22-01-2021   Italy    Parma    dew     56   4.0   5.0     4.0      1.25
# 37985  19-03-2021   Italy    Parma    dew    104  -4.0   1.0    -1.0     19.24
#
# ...

# %%
df_USA
# Out:
#               Date        Country           City      Specie  count   min  \
# 0       13-06-2021  UNITED STATES  Oklahoma City          o3     48   8.0
# 1       19-04-2021  UNITED STATES  Oklahoma City          o3     45   3.2
# 2       24-06-2021  UNITED STATES  Oklahoma City          o3     48  14.5
# 3       19-07-2021  UNITED STATES  Oklahoma City          o3     46  13.6
# 4       25-09-2021  UNITED STATES  Oklahoma City          o3     48  19.2
# ...            ...            ...            ...         ...    ...   ...
# 179360  05-02-2021  UNITED STATES     Fort Worth  wind-speed     23   0.4
# 179361  06-05-2021  UNITED STATES     Fort Worth  wind-speed     22   1.4
# 179362  29-05-2021  UNITED STATES     Fort Worth  wind-speed     22   3.2
# 179363  30-07-2021  UNITED STATES     Fort Worth  wind-speed     22   0.3
# 179364  15-08-2021  UNITED STATES     Fort Worth  wind-speed     22   0.9
#
#          max  median  variance
# 0       45.6    26.4   1207.36
# ...
