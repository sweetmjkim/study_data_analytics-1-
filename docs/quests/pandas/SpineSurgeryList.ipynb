# %% [markdown]
# <a href="https://colab.research.google.com/github/nohjuhyeon/study_data_analytics/blob/main/docs/quests/pandas/SpineSurgeryList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_spinesurgery = pd.read_csv("/content/SpineSurgeryList.csv")

# %%
df_spinesurgery
# Out:
#       Unnamed: 0    환자ID  Large Lymphocyte Location of herniation   ODI  가족력  \
# 0              0     1PT              22.8                      3  51.0  0.0
# 1              1     2PT              44.9                      4  26.0  0.0
# 2              2     3PT              53.0                      3   NaN  0.0
# 3              3     4PT              54.7                      4  18.0  0.0
# 4              4     5PT              53.8                      4   NaN  0.0
# ...          ...     ...               ...                    ...   ...  ...
# 1889        1889  1890PT              44.0                      1   NaN  0.0
# 1890        1890  1891PT              30.8                      2   NaN  0.0
# 1891        1891  1892PT              36.7                      3   NaN  0.0
# 1892        1892  1893PT              32.5                      2   NaN  0.0
# 1893        1893  1894PT              49.5                      2   NaN  0.0
#
# ...

# %%
df_spinesurgery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1894 non-null   int64
#  1   환자ID                    1894 non-null   object
#  2   Large Lymphocyte        1894 non-null   float64
#  3   Location of herniation  1894 non-null   int64
#  4   ODI                     462 non-null    float64
#  5   가족력                     1843 non-null   float64
#  6   간질성폐질환                  1894 non-null   int64
#  7   고혈압여부                   1894 non-null   int64
#  8   과거수술횟수                  1894 non-null   int64
#  9   당뇨여부                    1894 non-null   int64
#  10  말초동맥질환여부                1894 non-null   int64
#  11  빈혈여부                    1894 non-null   int64
#  12  성별                      1894 non-null   int64
#  13  스테로이드치료                 1894 non-null   int64
# ...

# %%
df_spinesurgery.columns
# Out:
# Index(['Unnamed: 0', '환자ID', 'Large Lymphocyte', 'Location of herniation',
#        'ODI', '가족력', '간질성폐질환', '고혈압여부', '과거수술횟수', '당뇨여부', '말초동맥질환여부', '빈혈여부',
#        '성별', '스테로이드치료', '신부전여부', '신장', '심혈관질환', '암발병여부', '연령', '우울증여부', '입원기간',
#        '입원일자', '종양진행여부', '직업', '체중', '퇴원일자', '헤모글로빈수치', '혈전합병증여부', '환자통증정도',
#        '흡연여부', '통증기간(월)', '수술기법', '수술시간', '수술실패여부', '수술일자', '재발여부', '혈액형',
#        '전방디스크높이(mm)', '후방디스크높이(mm)', '지방축적도', 'Instability', 'MF + ES',
#        'Modic change', 'PI', 'PT', 'Seg Angle(raw)', 'Vaccum disc', '골밀도',
#        '디스크단면적', '디스크위치', '척추이동척도', '척추전방위증'],
#       dtype='object')

# %%
df_spinesurgery.describe()
# Out:
#         Unnamed: 0  Large Lymphocyte         ODI          가족력       간질성폐질환  \
# count  1894.000000       1894.000000  462.000000  1843.000000  1894.000000
# mean    946.500000         39.270750   31.142857     0.049919     0.020063
# std     546.895023         13.675874   10.131304     0.217836     0.140254
# min       0.000000          0.000000    4.000000     0.000000     0.000000
# 25%     473.250000         30.700000   24.250000     0.000000     0.000000
# 50%     946.500000         40.200000   31.500000     0.000000     0.000000
# 75%    1419.750000         48.600000   38.000000     0.000000     0.000000
# max    1893.000000         89.000000   68.000000     1.000000     1.000000
#
#              고혈압여부       과거수술횟수         당뇨여부     말초동맥질환여부         빈혈여부  ...  \
# count  1894.000000  1894.000000  1894.000000  1894.000000  1894.000000  ...
# mean      0.130940     0.302534     0.062830     0.004224     0.024287  ...
# ...

# %%
df_spinesurgery['당뇨여부'].unique()
# Out:
# array([0, 1])

# %%
df_spinesurgery['과거수술횟수'].unique()
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ### data type 변환

# %%
df_spinesurgery['간질성폐질환'] = df_spinesurgery['간질성폐질환'].astype('object')

# %%
df_spinesurgery['Location of herniation'] = df_spinesurgery['Location of herniation'].astype('object')

# %%
df_spinesurgery['가족력'] = df_spinesurgery['가족력'].astype('object')

# %%
df_spinesurgery['고혈압여부'] = df_spinesurgery['고혈압여부'].astype('object')

# %%
df_spinesurgery['과거수술횟수'] = df_spinesurgery['과거수술횟수'].astype('object')

# %%
df_spinesurgery['당뇨여부'] = df_spinesurgery['당뇨여부'].astype('object')

# %%
df_spinesurgery['말초동맥질환여부'] = df_spinesurgery['말초동맥질환여부'].astype('object')

# %%
df_spinesurgery['빈혈여부'] = df_spinesurgery['빈혈여부'].astype('object')

# %%
df_spinesurgery['입원일자'] = df_spinesurgery['입원일자'].astype('object')

# %%
df_spinesurgery['성별'] = df_spinesurgery['성별'].astype('object')

# %%
df_spinesurgery['신장'] = df_spinesurgery['신장'].astype('object')

# %%
df_spinesurgery['연령'] = df_spinesurgery['연령'].astype('object')

# %%
df_spinesurgery['종양진행여부'] = df_spinesurgery['종양진행여부'].astype('object')

# %%
df_spinesurgery['퇴원일자'] = df_spinesurgery['퇴원일자'].astype('object')

# %%
df_spinesurgery['흡연여부'] = df_spinesurgery['흡연여부'].astype('object')

# %%
df_spinesurgery['수술실패여부'] = df_spinesurgery['수술실패여부'].astype('object')

# %%
df_spinesurgery['수술일자'] = df_spinesurgery['수술일자'].astype('object')

# %%
df_spinesurgery['재발여부'] = df_spinesurgery['재발여부'].astype('object')

# %%
df_spinesurgery['전방디스크높이(mm)'] = df_spinesurgery['전방디스크높이(mm)'].astype('object')

# %%
df_spinesurgery['후방디스크높이(mm)'] = df_spinesurgery['후방디스크높이(mm)'].astype('object')

# %%
df_spinesurgery['Instability'] = df_spinesurgery['Instability'].astype('object')

# %%
df_spinesurgery['Modic change'] = df_spinesurgery['Modic change'].astype('object')

# %%
df_spinesurgery['PI'] = df_spinesurgery['PI'].astype('object')

# %%
df_spinesurgery['PT'] = df_spinesurgery['PT'].astype('object')

# %%
df_spinesurgery['Seg Angle(raw)'] = df_spinesurgery['Seg Angle(raw)'].astype('object')

# %%
df_spinesurgery['Vaccum disc'] = df_spinesurgery['Vaccum disc'].astype('object')

# %%
df_spinesurgery['디스크위치'] = df_spinesurgery['디스크위치'].astype('object')

# %%
df_spinesurgery['척추전방위증'] = df_spinesurgery['척추전방위증'].astype('object')

# %%
df_spinesurgery.describe(include='object')
# Out:
#         환자ID  Location of herniation     가족력  간질성폐질환  고혈압여부  과거수술횟수  당뇨여부  \
# count   1894                    1894  1843.0    1894   1894    1894  1894
# unique  1894                       5     2.0       2      2       4     2
# top      1PT                       3     0.0       0      0       0     0
# freq       1                     657  1751.0    1856   1646    1499  1775
#
#         말초동맥질환여부  빈혈여부    성별    신장    연령      입원일자  종양진행여부    직업      퇴원일자  \
# count       1894  1894  1894  1894  1894      1894    1894  1479      1894
# unique         2     2     2    52    68      1051       2    17      1012
# top            0     0     1   170    47  20190129       0   사무직  20120229
# freq        1886  1848  1168   112   106        23    1888   449        46
#
#         헤모글로빈수치  혈전합병증여부  흡연여부  수술기법  수술실패여부      수술일자  재발여부   혈액형  \
# count    1893.0     1894  1894  1813    1894      1894  1894  1894
# unique    517.0        2     2     2       2       976     2     4
# ...

# %%
df_spinesurgery['척추전방위증'].unique()
# Out:
# array([0, 1])
